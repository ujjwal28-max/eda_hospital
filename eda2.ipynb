# %% [markdown]
# <a href="https://colab.research.google.com/github/ujjwal28-max/eda_hospital/blob/main/eda2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#eda 2

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/healthcare_dataset_with_hospitals.csv')

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Insurance Provider  55500 non-null  object
#  8   Billing Amount      55500 non-null  float64
#  9   Room Number         55500 non-null  int64
#  10  Admission Type      55500 non-null  object
#  11  Discharge Date      55500 non-null  object
#  12  Medication          55500 non-null  object
#  13  Test Results        55500 non-null  object
#  14  Hospital            55500 non-null  object
# ...

# %%
df['Age'].describe
# Out:
# <bound method NDFrame.describe of 0        30
# 1        62
# 2        76
# 3        28
# 4        43
#          ..
# 55495    42
# 55496    61
# 55497    38
# 55498    43
# 55499    53
# Name: Age, Length: 55500, dtype: int64>

# %%
df.sample(100)
# Out:
#                 Name  Age  Gender Blood Type Medical Condition  \
# 44571    Pooja Gupta   67  Female        AB+      Hypertension
# 37766     Meera Nair   81  Female        AB-          Diabetes
# 45354      Anil Bose   36    Male         B-            Cancer
# 33211   Deepak Gupta   59    Male         O-            Cancer
# 26461    Priya Gupta   68  Female         O+          Diabetes
# ...              ...  ...     ...        ...               ...
# 11090   Rajesh Verma   74    Male         O+      Hypertension
# 45266   Sunita Joshi   61  Female        AB+            Cancer
# 40566  Rajesh Sharma   37    Male        AB-            Asthma
# 45244     Amit Gupta   24    Male        AB-         Arthritis
# 27705      Neha Nair   38  Female         O-            Asthma
#
#       Date of Admission             Doctor Insurance Provider  Billing Amount  \
# 44571        2020-07-10   Dr. Anil Trivedi              Cigna    27133.555919
# ...

# %%
df.nunique()
# Out:
# Name                    400
# Age                      77
# Gender                    2
# Blood Type                8
# Medical Condition         6
# Date of Admission      1827
# Doctor                   20
# Insurance Provider        5
# Billing Amount        50000
# Room Number             400
# Admission Type            3
# Discharge Date         1856
# Medication                5
# Test Results              3
# Hospital                 10
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# Hospital              0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.countplot(df['Admission Type'])
# Out:
# <Axes: xlabel='count', ylabel='Admission Type'>

# %%
df['Admission Type'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Admission Type'>

# %%
df['Blood Type'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Age'].mean()
# Out:
# 51.53945945945946

# %%
df['Age'].min()
# Out:
# 13

# %%
df['Age'].max()
# Out:
# 89

# %%
df['Billing Amount'].min()
# Out:
# -2008.4921398591305

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
# Out:
# (array([2803., 6229., 6211., 6069., 6268., 6204., 6225., 6105., 6211.,
#         3175.]),
#  array([-2008.49213986,  3468.78474777,  8946.06163541, 14423.33852304,
#         19900.61541067, 25377.89229831, 30855.16918594, 36332.44607357,
#         41809.7229612 , 47286.99984884, 52764.27673647]),
#  <BarContainer object of 10 artists>)

# %%
sns.displot(df['Billing Amount'])

# %%
sns.heatmap(pd.crosstab(df['Gender'],df['Admission Type']))
# Out:
# <Axes: xlabel='Admission Type', ylabel='Gender'>

# %%
sns.heatmap(pd.crosstab(df['Gender'],df['Blood Type']))
# Out:
# <Axes: xlabel='Blood Type', ylabel='Gender'>

# %%
sns.heatmap(pd.crosstab(df['Test Results'],df['Hospital']))
# Out:
# <Axes: xlabel='Hospital', ylabel='Test Results'>

# %%
df['Medical Condition'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
negative_billing = df[df['Billing Amount'] < 0]
negative_billing
# Out:
#                   Name  Age  Gender Blood Type Medical Condition  \
# 132      Rahul Trivedi   32  Female        AB-            Cancer
# 799       Varun Sharma   49  Female        AB-            Asthma
# 1018   Ananya Malhotra   60    Male         A+      Hypertension
# 1421       Kiran Patel   74  Female         O+            Asthma
# 2103    Varun Malhotra   72  Female         B-          Diabetes
# ...                ...  ...     ...        ...               ...
# 52894   Sunita Trivedi   23    Male        AB-          Diabetes
# 53204     Deepak Verma   55    Male         A+      Hypertension
# 53232     Manoj Sharma   68  Female         B+      Hypertension
# 54136       Anil Verma   64    Male         O+            Cancer
# 55276      Rahul Gupta   58  Female         O-      Hypertension
#
#       Date of Admission            Doctor Insurance Provider  Billing Amount  \
# 132          2019-11-05   Dr. Manoj Desai              Aetna     -502.507813
# ...
